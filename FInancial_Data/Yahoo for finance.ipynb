# %% [markdown]
# # Financial Data

# %% [markdown]
# ## Using yahoo for data

# %%
import yfinance as yf

# %%
data= yf.download(tickers="IDFC.NS", period= "1d", interval="5m")
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2023-07-05 09:15:00+05:30  111.449997  112.300003  110.750000  112.300003
# 2023-07-05 09:20:00+05:30  112.199997  113.150002  112.199997  113.099998
# 2023-07-05 09:25:00+05:30  113.349998  113.750000  113.349998  113.599998
# 2023-07-05 09:30:00+05:30  113.550003  114.849998  113.550003  114.550003
# 2023-07-05 09:35:00+05:30  114.550003  115.400002  114.400002  114.500000
# ...                               ...         ...         ...         ...
# 2023-07-05 15:05:00+05:30  114.199997  114.349998  114.099998  114.199997
# 2023-07-05 15:10:00+05:30  114.300003  114.300003  114.150002  114.250000
# 2023-07-05 15:15:00+05:30  114.300003  114.550003  114.199997  114.500000
# 2023-07-05 15:20:00+05:30  114.500000  114.550003  114.150002  114.199997
# 2023-07-05 15:25:00+05:30  114.199997  114.550003  114.199997  114.550003
#
# ...

# %%
#!pip install yahooquery
from yahooquery import Ticker
# Out:
# ...
#      -------------------------------------- 49.8/49.8 kB 628.3 kB/s eta 0:00:00
# ...

# %%
IDFC=Ticker("IDFC.NS")

# %%
IDFC.financial_data
# Out:
# {'IDFC.NS': {'maxAge': 86400,
#   'currentPrice': 114.3,
#   'recommendationMean': 3.0,
#   'recommendationKey': 'hold',
#   'totalCash': 3774599936,
#   'totalCashPerShare': 2.362,
#   'totalDebt': 0,
#   'quickRatio': 7.173,
#   'currentRatio': 8.822,
#   'totalRevenue': 1531000064,
#   'revenuePerShare': 0.958,
#   'returnOnAssets': 0.06459,
#   'returnOnEquity': 0.06561,
#   'operatingCashflow': 41282101248,
#   'earningsGrowth': 16.377,
#   'revenueGrowth': 23.235,
#   'grossMargins': 1.0,
#   'ebitdaMargins': 0.0,
#   'operatingMargins': 0.59151,
#   'profitMargins': 27.719719,
#   'financialCurrency': 'INR'}}

# %%
IDFC.key_stats
# Out:
# {'IDFC.NS': {'maxAge': 1,
#   'priceHint': 2,
#   'enterpriseValue': 159682953216,
#   'profitMargins': 27.719719,
#   'floatShares': 927122251,
#   'sharesOutstanding': 1599980032,
#   'heldPercentInsiders': 0.24572,
#   'heldPercentInstitutions': 0.33326,
#   'beta': 1.069863,
#   'impliedSharesOutstanding': 1599980032,
#   'category': None,
#   'bookValue': 72.581,
#   'priceToBook': 1.5747923,
#   'fundFamily': None,
#   'legalType': None,
#   'lastFiscalYearEnd': '2023-03-31 05:30:00',
#   'nextFiscalYearEnd': '2024-03-31 05:30:00',
#   'mostRecentQuarter': '2023-03-31 05:30:00',
#   'earningsQuarterlyGrowth': 16.446,
#   'netIncomeToCommon': 6732899840,
#   'trailingEps': 4.3,
#   'forwardEps': 4.69,
#   'lastSplitFactor': None,
#   'enterpriseToRevenue': 104.3,
#   '52WeekChange': 104.97697,
#   'SandP52WeekChange': 15.877687,
#   'lastDividendValue': 11.0,
#   'lastDividendDate': 1676246400}}

# %%
IDFC.balance_sheet()
# Out:
#           asOfDate periodType currencyCode  AccountsPayable  \
# symbol
# IDFC.NS 2020-03-31        12M          INR      137400000.0
# IDFC.NS 2021-03-31        12M          INR      127000000.0
# IDFC.NS 2022-03-31        12M          INR              0.0
# IDFC.NS 2023-03-31        12M          INR              0.0
#
#          AccumulatedDepreciation  AdditionalPaidInCapital  \
# symbol
# IDFC.NS             -442000000.0             2.523470e+10
# IDFC.NS             -165300000.0             2.523470e+10
# IDFC.NS              -21000000.0             2.523780e+10
# IDFC.NS                      NaN                      NaN
#
#          AvailableForSaleSecurities  BuildingsAndImprovements  CapitalStock  \
# symbol
# IDFC.NS                4.190100e+09               962400000.0  1.596360e+10
# IDFC.NS                5.656900e+09               433500000.0  1.596360e+10
# IDFC.NS                3.010300e+09                       0.0  1.596440e+10
# ...

# %%
IDFC.income_statement()
# Out:
#           asOfDate periodType currencyCode  BasicAverageShares  BasicEPS  \
# symbol
# IDFC.NS 2019-12-31        TTM          INR                 NaN       NaN
# IDFC.NS 2020-03-31        12M          INR        1.596358e+09     -6.24
# IDFC.NS 2021-03-31        12M          INR        1.596358e+09     -2.11
# IDFC.NS 2022-03-31        12M          INR        1.600750e+09      0.40
# IDFC.NS 2022-12-31        TTM          INR                 NaN       NaN
# IDFC.NS 2023-03-31        12M          INR        1.597850e+09     26.56
# IDFC.NS 2023-03-31        TTM          INR                 NaN       NaN
#
#          DepreciationAndAmortizationInIncomeStatement  \
# symbol
# IDFC.NS                                           NaN
# IDFC.NS                                   315700000.0
# IDFC.NS                                   202700000.0
# IDFC.NS                                    35500000.0
# IDFC.NS                                    35400000.0
# ...

# %%
IDFC.cash_flow(trailing = False)
#it trailing = TRUE (by default) gives the value to the current date no the end of financial year
# Out:
#           asOfDate periodType currencyCode  BeginningCashPosition  \
# symbol
# IDFC.NS 2020-03-31        12M          INR           1.500900e+09
# IDFC.NS 2021-03-31        12M          INR           6.779000e+09
# IDFC.NS 2022-03-31        12M          INR           4.211000e+08
# IDFC.NS 2023-03-31        12M          INR           2.864700e+09
#
#          CapitalExpenditure  CashDividendsPaid  \
# symbol
# IDFC.NS        -650200000.0      -6.309700e+09
# IDFC.NS                 NaN                NaN
# IDFC.NS                 NaN                NaN
# IDFC.NS                 NaN      -1.919630e+10
#
#          ChangeInCashSupplementalAsReported  ChangeInOtherCurrentAssets  \
# symbol
# IDFC.NS                        5.278100e+09                 909900000.0
# IDFC.NS                       -6.357900e+09                 109500000.0
# IDFC.NS                        2.443600e+09                 233700000.0
# IDFC.NS                       -1.285300e+09                 -27000000.0
#
# ...
